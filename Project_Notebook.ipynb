# %% [markdown]
# # Multi-Disease Prediction System
# Predicting Diabetes, Heart Disease, and Kidney Disease.

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# Diabetes Model
diabetes_data = pd.DataFrame({
    'Pregnancies': [1, 8, 1, 1, 0], 'Glucose': [85, 183, 89, 137, 116], 
    'BP': [66, 64, 66, 40, 74], 'Skin': [29, 0, 23, 35, 0], 
    'Insulin': [0, 0, 94, 168, 0], 'BMI': [26.6, 23.3, 28.1, 43.1, 25.6], 
    'DPF': [0.351, 0.672, 0.167, 2.288, 0.201], 'Age': [31, 32, 21, 33, 30], 
    'Outcome': [0, 1, 0, 1, 0]
})
X_d = diabetes_data.drop('Outcome', axis=1)
y_d = diabetes_data['Outcome']
d_model = RandomForestClassifier().fit(X_d, y_d)

print('Diabetes Model Trained.')
